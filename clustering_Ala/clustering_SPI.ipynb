# %%
import pandas as pd
import numpy as np

from RGCPD import RGCPD
from RGCPD import BivariateMI
import class_BivariateMI, functions_pp
from stat_models_cont import ScikitModel
from sklearn.linear_model import Ridge
from sklearn.linear_model import LogisticRegressionCV
import func_models as fc_utils

# %load_ext autoreload
# %autoreload 2

# main directory is the directory of this notebook

import os, inspect
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# my main directory (which contains folders with data etc)
my_main_dir = 'C:\\Users\\alicj\\Desktop\\WORK'
data_path = os.path.join(my_main_dir, 'data')
# Out:
# Not able to load in plotting modules, check installment of networkx

# %%
from RGCPD import core_pp, functions_pp
import func_SPI_new
import xarray as xr
import numpy as np

# %%
from clustering import clustering_temporal as ct

# %%
spi3 = core_pp.import_ds_lazy('C:\\Users\\alicj\\Desktop\\WORK\\data\\Own_SPI_3.nc')

# %%
var_filename = 'C:\\Users\\alicj\\Desktop\\WORK\\data\\Own_SPI_3.nc'

# %%
mask = None
dimension = 'temporal'
kwrgs_load={'selbox':[0, 360,-90, 90], 'tfreq':[1, 3, 4]}
kwrgs_clust={'n_clusters':[3, 4]}
clustermethodkey = 'AgglomerativeClustering'

xrclustered_temp, results_temp = ct.sklearn_clustering(var_filename, mask, dimension, kwrgs_load, clustermethodkey, kwrgs_clust)
# Out:
# no mask given, entire array of box [30.0, 35.25, -17.5, -14.0] will be clustered
# clustering tfreq: 4, n_clusters: 4

# %%
levels = np.linspace(-0.3, 0.3, 100)
#xrclustered_temp[0][0][np.where(xrclustered_temp[0][0]['time']['cluster'] == 1)].mean('time').plot(levels = levels)
xrclustered_temp[0][0][np.where(xrclustered_temp[0][0]['time']['cluster'] == 3)].mean('time').plot(levels = levels)
#xrclustered_temp[0][0][np.where(xrclustered_temp[0][0]['time']['cluster'] == 2)].mean('time').plot(levels = levels)

# %%
xrclustered_temp[0][0][np.where(xrclustered_temp[0][0]['time']['cluster'] == 1)].mean('time').plot(levels = levels)

# %%
xrclustered_temp[0][0][np.where(xrclustered_temp[0][0]['time']['cluster'] == 2)].mean('time').plot(levels = levels)

# %%
moz_data = core_pp.import_ds_lazy('C:\\Users\\alicj\\Desktop\\WORK\\data\\moz_rainfall_sa.nc')

# %%
moz_data
# Out:
# <xarray.DataArray 'rainfall' (time: 480, longitude: 102, latitude: 76)>
# [3720960 values with dtype=int64]
# Coordinates:
#   * time       (time) datetime64[ns] 1981-01-01 1981-02-01 ... 2020-12-01
#   * longitude  (longitude) float64 30.23 30.27 30.32 30.38 ... 35.18 35.23 35.27
#   * latitude   (latitude) float64 -17.68 -17.62 -17.57 ... -14.03 -13.97 -13.93
